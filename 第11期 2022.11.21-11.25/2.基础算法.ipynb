# %%
1+1
# Out:
# 2

# %%
1+1
# Out:
# 2

# %% [markdown]
# # 10：04继续

# %%
import pandas as pd

columns_names = ['formula', 'db_center', 'ad_energy']
data = pd.read_csv('db_center.csv', names = columns_names)
data
# Out:
#   formula  db_center  ad_energy
# 0  Cu12Co      -1.33     -0.547
# 1  Cu12Rh      -1.57     -0.591
# 2  Cu12Ir      -1.74     -0.420
# 3  Cu12Ni      -1.21     -0.674
# 4  Cu12Pd      -2.01     -0.500
# 5  Cu12Pt      -1.78     -0.391
# 6    Cu13      -2.33     -0.316
# 7  Cu12Ag      -4.13     -0.201
# 8  Cu12Au      -3.12     -0.298

# %%
X = data['db_center'].values.reshape(-1, 1)
y = data['ad_energy'].values

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
coef = lr.coef_
intercept = lr.intercept_
print(coef, intercept)
# Out:
# [-0.14221031] -0.7412535628655477

# %%
R2 = lr.score(X, y)
R2
# Out:
# 0.7646612597264623

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(y_true = y, y_pred = lr.predict(X))
mse = mean_squared_error(y_true = y, y_pred = lr.predict(X))

print('哈哈，MAE=', mae)
print('MSE=', mse)
# Out:
# 哈哈，MAE= 0.05998761337416594
# MSE= 0.004916336690142974

# %%
lr.predict([[-2.2],
            [-2.3]])
# Out:
# array([-0.42839089, -0.41416986])

# %% [markdown]
# # 11:13继续

# %%
import matplotlib.pyplot as plt

x = data['db_center'].values
plt.scatter(x, y, label = 'actual value')
plt.plot(x, lr.predict(X), color = 'red', label = 'predict value')
plt.legend()
plt.show()
