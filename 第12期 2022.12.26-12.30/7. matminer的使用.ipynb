# %%
from matminer.datasets import load_dataset

df = load_dataset('expt_gap', data_home = '.')
df
# Out:
#            formula  gap expt
# 0     Hg0.7Cd0.3Te      0.35
# 1             CuBr      3.08
# 2              LuP      1.30
# 3         Cu3SbSe4      0.40
# 4              ZnO      3.44
# ...            ...       ...
# 6349       Tm2MgTl      0.00
# 6350        Nb5Ga4      0.00
# 6351        Tb2Sb5      0.00
# 6352       Lu2AlTc      0.00
# 6353        CeZnPO      0.00
#
# [6354 rows x 2 columns]

# %%
df.loc[df['formula']=='CuBr']
# Out:
#      formula  gap expt
# 1       CuBr      3.08
# 16      CuBr      2.94
# 455     CuBr      3.08
# 457     CuBr      2.91
# 1705    CuBr      3.07
# 2783    CuBr      2.90
# 2789    CuBr      3.02
# 3774    CuBr      2.99

# %%
df_el = load_dataset('elastic_tensor_2015', data_home = '.')
df_el
# Out:
#      material_id    formula  nsites  space_group      volume  \
# 0       mp-10003    Nb4CoSi      12          124  194.419802
# 1       mp-10010  Al(CoSi)2       5          164   61.987320
# 2       mp-10015       SiOs       2          221   25.952539
# 3       mp-10021         Ga       4           63   76.721433
# 4       mp-10025      SiRu2      12           62  160.300999
# ...          ...        ...     ...          ...         ...
# 1176     mp-9961     Ti2CdC       8          194  121.520152
# 1177     mp-9969       ScSi       8           63  145.392095
# 1178     mp-9972        YSi       8           63  174.123748
# 1179      mp-998      Al2Cu      12          140  179.147816
# 1180    mp-21855    VCu3Se4       8          215  180.206796
#
#                                               structure  elastic_anisotropy  \
# 0     [[0.94814328 2.07280467 2.5112    ] Nb, [5.273...            0.030688
# 1     [[0. 0. 0.] Al, [1.96639263 1.13529553 0.75278...            0.266910
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(df_el['K_VRH'], color = 'g', edgecolor = 'k', alpha = 0.75,
        bins = [0, 50, 100, 150, 200, 250, 300, 350, 400])
plt.show()

# %%
plt.hist(df_el['K_VRH'], density = True, color = 'g',
         edgecolor = 'k', alpha = 0.75,
        bins = [0, 50, 100, 150, 200, 250, 300, 350, 400])
plt.show()

# %%
x = df_el['G_VRH']
y = df_el['K_VRH']
z = df_el['poisson_ratio']
plt.scatter(x, y, c = z, edgecolor = 'k', cmap = 'bwr')
plt.xlim(0, 300)
plt.colorbar()
plt.show()

# %% [markdown]
# # 15:10继续
